# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
#iris
iris= load_iris()

x=iris.data
y= iris.target


xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

cls=DecisionTreeClassifier()
cls=cls.fit(xtrain,ytrain)

predict=cls.predict(xtest)
accuracy=accuracy_score(ytest,predict)
print(accuracy)

# var=[[.2,.3,.2,.2]]
# result=cls.predict(var)[0]
# iris.target_names[result]

plt.figure(figsize=(10,10))
plot_tree(cls,filled=True)
# Out:
# 0.9555555555555556
# [Text(0.4, 0.9, 'X[3] <= 0.8\ngini = 0.665\nsamples = 105\nvalue = [36, 32, 37]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(0.5, 0.7, 'X[3] <= 1.65\ngini = 0.497\nsamples = 69\nvalue = [0, 32, 37]'),
#  Text(0.2, 0.5, 'X[2] <= 5.0\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.3, 0.3, 'X[0] <= 6.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.5, 'X[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]'),
#  Text(0.7, 0.3, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
# np.random.seed(15) #Seed ensures the same sequence of randomness
# data = {
#     'Color':np.random.choice(['Red','Blue','Green','Black','White'],25),
#     'Brand':np.random.choice(['Ford','Ferrari','Nissan','Volkswagen','Cheverlot'],25),
#     'Year':np.random.randint(2018,2023,size=25),
#     'Seats':np.random.randint(4,8,25),
#     'Kilometers_Run':np.random.randint(35000,65000,25),
#     'Buy':np.random.choice(['Yes','No'],25)
# }
# df = pd.DataFrame(data)
# # print(df)


data={
    "brand":["Mercedez","Volvo","Maruti","Audi"],
    "year":[2020,2018,2013,2016],
    "color":["black","white","red","blue"],
    "mileage":[25,22,26,18],
    "buy":["yes","yes","no","no"]
}
df= pd.DataFrame(data)

df['brand']=df['brand'].map({"Mercedez":1,"Volvo":2,"Maruti":3,"Audi":4})
df["color"]=df["color"].map({"black":1,"white":2,"red":3,"blue":4})
df["buy"]=df["buy"].map({"yes":1,"no":2})

x=df[["brand","year","color","mileage"]]
y=df["buy"]

clf=DecisionTreeClassifier()
clf=clf.fit(x,y)

plt.figure(figsize=(10,10))
plot_tree(clf,filled=True,feature_names=x.columns, class_names=['No', 'Yes'])
# Out:
# [Text(0.5, 0.75, 'color <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = No'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes')]

# %%
data=pd.read_csv("Cars.csv")
pd.DataFrame(data)


# Convert categorical variables to numerical
df['Color'] = df['Color'].map({'Red': 1, 'Yellow': 2, 'Blue': 3})
df['Buy'] = df['Buy'].map({'Yes': 1, 'No': 0})

# Features and target variable
X = df[['Color', 'Model_Year', 'Mileage', 'Model']]
y = df['Buy']

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf = clf.fit(X, y)

# Plot the decision tree
plt.figure(figsize=(10, 8))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True, rounded=True)
plt.show()
